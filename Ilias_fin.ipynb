# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Lecture des données
df1 = pd.read_csv("table1.csv")
df=df1.copy()
#df['year']= df['year'].str.replace(",",".")
df["year"]=pd.to_numeric(df['year'])
df['Life Ladder']= df['Life Ladder'].str.replace(",",".")
df['Log GDP per capita']= df['Log GDP per capita'].str.replace(",",".")
df['Social support']= df['Social support'].str.replace(",",".")
df['Healthy life expectancy at birth']= df['Healthy life expectancy at birth'].str.replace(",",".")
df['Freedom to make life choices']= df['Freedom to make life choices'].str.replace(",",".")
df['Generosity']= df['Generosity'].str.replace(",",".")
df['Perceptions of corruption']= df['Perceptions of corruption'].str.replace(",",".")
df['Positive affect']= df['Positive affect'].str.replace(",",".")
df['Negative affect']= df['Negative affect'].str.replace(",",".")

df['Life Ladder']=pd.to_numeric(df['Life Ladder'])
df['Log GDP per capita']=pd.to_numeric(df['Log GDP per capita'])
df['Social support']=pd.to_numeric(df['Social support'])
df['Healthy life expectancy at birth']=pd.to_numeric(df['Healthy life expectancy at birth'])
df['Freedom to make life choices']=pd.to_numeric(df['Freedom to make life choices'])
df['Generosity']=pd.to_numeric(df['Generosity'])
df['Perceptions of corruption']=pd.to_numeric(df['Perceptions of corruption'])
df['Positive affect']=pd.to_numeric(df['Positive affect'])
df['Negative affect']=pd.to_numeric(df['Negative affect'])

df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
dfmatrice=df.copy()
dfmatrice = dfmatrice.drop('Country name', axis=1)

sns.heatmap(dfmatrice.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(dfmatrice.corr(), annot=False, cmap='Greens')
plt.title("Matrice de corrélation entre les différents indicateurs\n", fontsize=18, color='#009432')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation entre les différents indicateurs\n')

# %%
df["Log GDP per capita"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
fig, axes = plt.subplots(figsize=(10,10))
axes.set_xlim(-1,1)
axes.set_ylim(-1,1)
X = df[['Log GDP per capita', 'Life Ladder', 'Generosity', 'Social support']]
for j in range(4):
   plt.annotate(X.columns[j],(corvar[j,0],corvar[j,1]))
plt.plot([-1,1],[0,0],color='red',linestyle='-',linewidth=1)
plt.plot([0,0],[-1,1],color='red',linestyle='-',linewidth=1)
cercle = plt.Circle((0,0),1,color='blue',fill=False)
axes.add_artist(cercle)
plt.title('Cercle de corrélation\n', fontsize=20, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ilias\COURS_INFO\Hackathon\pe-hackathon\coucou.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> X = df[['Log GDP per capita', 'Life Ladder', 'Generosity', 'Social support']]
#       <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> for j in range(4):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>    plt.annotate(X.columns[j],(corvar[j,0],corvar[j,1]))
#       <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> plt.plot([-1,1],[0,0],color='red',linestyle='-',linewidth=1)
# ...

# %%
plt.plot(df["Log GDP per capita"], df["Healthy life expectancy at birth"])
plt.show()

# %%
df.plot.scatter(x='Life Ladder',y='Log GDP per capita')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ilias\COURS_INFO\Hackathon\pe-hackathon\coucou.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df.plot.scatter(x='Life Ladder',y='Log GDP per capita')
#
# File c:\miniconda\Lib\site-packages\pandas\plotting\_core.py:1751, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1663 def scatter(
#    1664     self,
#    1665     x: Hashable,
#    (...)
#    1669     **kwargs,
#    1670 ) -> PlotAccessor:
#    1671     """
#    1672     Create a scatter plot with varying marker point size and color.
#    1673
#    (...)
#    1749         ...                       colormap='viridis')
#    1750     """
# -> 1751     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# ...

# %%
#df_2022=[df['year']=="2022"]
mask2022 = df['year']==2022
df2022=df[mask2022].copy()
df2022.sort_values('Log GDP per capita')
sns.relplot(df2022, x='Log GDP per capita', y='Healthy life expectancy at birth')
# Out:
# c:\miniconda\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df2022
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13    Afghanistan  2022        1.281                 NaN           0.228
# 28        Albania  2022        5.212               9.626           0.724
# 59      Argentina  2022        6.261              10.011           0.893
# 75        Armenia  2022        5.382               9.668           0.811
# 91      Australia  2022        7.035              10.854           0.942
# ...           ...   ...          ...                 ...             ...
# 2104      Uruguay  2022        6.671              10.084           0.905
# 2120   Uzbekistan  2022        6.016               8.990           0.879
# 2137    Venezuela  2022        5.949                 NaN           0.899
# 2154      Vietnam  2022        6.267               9.333           0.879
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
#nécessite la librairie scikit-learn
from sklearn.preprocessing import StandardScaler as sc
X=df2022.copy()
sc = StandardScaler()
X = X.drop('Country name', axis=1)
n = X.shape[0]
p = X.shape[1]
sc = StandardScaler()
Z = sc.fit_transform(X)
from sklearn.decomposition import PCA
acp = PCA(svd_solver='full')
coord = acp.fit_transform(Z)
bs = 1/numpy.arange(p,0,-1)
bs = numpy.cumsum(bs)
bs = bs[::-1]

#eigval = (n-1)/n*acp.explained_variance_
#plt.plot(numpy.arange(1,p+1),eigval)
#plt.title("Scree plot")
#plt.ylabel("Eigen values")
#plt.xlabel("Factor number")
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ilias\COURS_INFO\Hackathon\pe-hackathon\coucou.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> from sklearn.decomposition import PCA
#      <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> acp = PCA(svd_solver='full')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> coord = acp.fit_transform(Z)
#      <a href='vscode-notebook-cell:/c%3A/Users/ilias/COURS_INFO/Hackathon/pe-hackathon/coucou.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> #eigval = (n-1)/n*acp.explained_variance_
#
# ...
